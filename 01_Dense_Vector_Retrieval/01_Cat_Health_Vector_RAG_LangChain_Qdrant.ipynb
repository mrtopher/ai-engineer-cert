# %% [markdown]
# # Your First Vector RAG Application: Cat Health Assistant
#
# In this notebook, we will build a dense vector retrieval application using **LangChain v1**, **OpenAI embeddings**, and **Qdrant** as an in-memory vector database.
#
# The goal is to understand the core RAG loop:
#
# 1. Load a cat health guideline PDF
# 2. Split it into smaller chunks
# 3. Embed those chunks
# 4. Store the embeddings in Qdrant
# 5. Retrieve relevant chunks for a question
# 6. Generate an answer grounded in the retrieved context
#
# > Note: This notebook expects Python 3.12 and uses uv for dependency management.
#
# > Note: This is a vector RAG lesson, not a veterinary care tool. The assistant should answer from the PDF and point users to a veterinarian for diagnosis, treatment, medication, or urgent care decisions.

# %% [markdown]
# ## Table of Contents
#
# - Task 1: Environment Setup
# - Task 2: Embedding Similarity Primer
# - Task 3: Documents - Loading the Cat Health Guideline PDF
# - Task 4: Chunking the Documents
# - Task 5: Embeddings and Qdrant
# - Task 6: Retrieval with Scores
# - Task 7: Retrieval Augmented Generation
# - Activity: Tune Retrieval Quality

# %% [markdown]
# ## Task 1: Environment Setup
#
# From the `01_Dense_Vector_Retrieval` folder, install dependencies with uv:
#
# ```bash
# uv sync
# ```
#
# Then open this notebook in Cursor or VS Code and select the Python/Jupyter environment created by uv.

# %% [markdown]
# ### Imports
#
# LangChain v1 separates integrations into partner packages. We will use:
#
# - `langchain_community` for PDF loading
# - `langchain_text_splitters` for chunking
# - `langchain_openai` for chat and embedding models
# - `langchain_qdrant` for the Qdrant vector store

# %%
from pathlib import Path
from math import sqrt
from getpass import getpass
import os

from langchain_community.document_loaders import PyPDFLoader
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_qdrant import QdrantVectorStore
from langchain_text_splitters import RecursiveCharacterTextSplitter
# Out:
# /var/folders/dp/5cdqzvln65n66jy4w70d9fch0000gn/T/ipykernel_7501/4147450701.py:6: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %% [markdown]
# ### OpenAI API Key
#
# The chat model and embedding model both use OpenAI. If `OPENAI_API_KEY` is not already set in your environment, this cell will ask for it securely.

# %%
if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = getpass("OpenAI API Key: ")

# %% [markdown]
# ## Task 2: Embedding Similarity Primer
#
# Before we load a full PDF, let's make dense vector retrieval less mysterious.
#
# An embedding model turns text into a list of numbers. Texts with related meaning should land closer together in that vector space.
#
# A common way to score closeness is **cosine similarity**:
#
# ```text
# cosine_similarity(a, b) = dot_product(a, b) / (length(a) * length(b))
# ```
#
# The intuition: if two vectors point in a similar direction, their cosine similarity is higher. Vector databases like Qdrant use this same idea, but at a much larger scale.

# %%
embedding_model = "text-embedding-3-small"
embeddings = OpenAIEmbeddings(model=embedding_model)

example_texts = [
    "king",
    "queen",
    "banana",
    "cat",
    "veterinarian",
    "cat health guidelines",
]

example_vectors = dict(zip(example_texts, embeddings.embed_documents(example_texts)))


def cosine_similarity(vector_a: list[float], vector_b: list[float]) -> float:
    dot_product = sum(a * b for a, b in zip(vector_a, vector_b))
    length_a = sqrt(sum(a * a for a in vector_a))
    length_b = sqrt(sum(b * b for b in vector_b))
    return dot_product / (length_a * length_b)


comparison_pairs = [
    ("king", "queen"),
    ("king", "banana"),
    ("cat", "veterinarian"),
    ("cat", "cat health guidelines"),
]

for left, right in comparison_pairs:
    score = cosine_similarity(example_vectors[left], example_vectors[right])
    print(f"{left:>22} <> {right:<22} score={score:.3f}")
# Out:
#                   king <> queen                  score=0.591
#                   king <> banana                 score=0.310
#                    cat <> veterinarian           score=0.356
#                    cat <> cat health guidelines  score=0.496

# %% [markdown]
# A few important notes:
#
# - The score is useful for ranking, not as an absolute truth about meaning.
# - Different embedding models can produce different scores.
# - In RAG, we embed each document chunk once, then embed the user's query and search for the nearest chunk vectors.
#
# That is the retrieval part of RAG.

# %% [markdown]
# ## Task 3: Documents
#
# LangChain represents loaded text as `Document` objects. A `Document` has:
#
# - `page_content`: the text
# - `metadata`: information such as source file and page number
#
# We will load one `Document` per PDF page, then split those pages into smaller chunks.

# %% [markdown]
# ### Course PDF
#
# This notebook uses the bundled cat health guideline PDF at:
#
# ```text
# 01_Dense_Vector_Retrieval/data/cat_health_guidelines.pdf
# ```
#
# The next cell checks that the course material is present before we start loading pages.

# %%
pdf_path = Path("data/cat_health_guidelines.pdf")

if not pdf_path.exists():
    raise FileNotFoundError(
        f"Expected the cat health guideline PDF at: {pdf_path.resolve()}\n"
        "The bundled course PDF is missing from this copy of the materials."
    )

# %% [markdown]
# ### Load the PDF
#
# `PyPDFLoader` extracts text from text-based PDFs. If the PDF is scanned images, this loader may return little or no text, and OCR would be needed.

# %%
loader = PyPDFLoader(str(pdf_path))
pages = loader.load()

for page in pages:
    page.metadata["source"] = pdf_path.name
    page.metadata["document_type"] = "cat_health_guideline"

pages = [page for page in pages if page.page_content.strip()]

if not pages:
    raise ValueError(
        "The PDF loaded, but no extractable text was found. "
        "This usually means the PDF is scanned and needs OCR first."
    )

print(f"Loaded {len(pages)} text-containing PDF pages.")
# Out:
# Loaded 22 text-containing PDF pages.

# %%
print(pages[0].page_content[:750])
print("\nMetadata:", pages[0].metadata)
# Out:
# VETERINARY PRACTICE GUIDELINES
# 2021 AAHA/AAFP Feline Life Stage Guidelines*
# Jessica Quimby, DVM, PhD, DACVIM y, Shannon Gowland, DVM, DABVP y, Hazel C. Carney, DVM, MS, DABVP,
# Theresa DePorter, DVM, MRCVS, DACVB, DECAWBM, Paula Plummer, LVT, VTS (ECC, SAIM), Jodi Westropp,
# DVM, PhD, DACVIM
# ABSTRACT
# The guidelines, authored by a Task Force ofexperts in feline clinical medicine, are an update and extension of the AAFP–AAHA
# Feline Life Stage Guidelines published in 2010. The guidelines are published simultaneously in theJournal of Feline Medicine and
# Surgery(volume 23, issue 3, pages 211–233, DOI: 10.1177/1098612X21993657) and theJournal of the American Animal Hospital
# Association(volume 57, issue 2, pages 51–72, DOI: 10.5326/JAAHA-MS-7189). A
#
# Metadata: {'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 0, 'page_label': '1', 'document_type': 'cat_health_guideline'}

# %% [markdown]
# #### ❓Question #1
#
# Why is metadata important for a RAG application?
#
# ##### ✅ Answer:
#
# Metadata matters in RAG because retrieval based purely on semantic similarity isn't enough on its own. You likely need to know about a chunk, not just what it says. Metadata provides capabilities like filtering/scoping, access control and security, etc.

# %% [markdown]
# ## Task 4: Chunking the Documents
#
# A full PDF page can be too large or too mixed-topic for high-quality retrieval. We split pages into overlapping chunks so each chunk has enough local context but is still focused.
#
# Here we will start with chunks of 1,000 characters and 200 characters of overlap. The chunk size controls how much text each vector represents; the overlap keeps nearby context from being lost at chunk boundaries.
#
# `RecursiveCharacterTextSplitter` tries to split on natural boundaries first, such as paragraphs and line breaks, before falling back to smaller separators.

# %%
chunk_size = 500
chunk_overlap = 100

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=chunk_size,
    chunk_overlap=chunk_overlap,
    add_start_index=True,
)

splits = text_splitter.split_documents(pages)

print(f"Split {len(pages)} pages into {len(splits)} chunks.")
print(f"Chunk size: {chunk_size} characters")
print(f"Chunk overlap: {chunk_overlap} characters")
# Out:
# Split 22 pages into 263 chunks.
# Chunk size: 500 characters
# Chunk overlap: 100 characters

# %%
sample_chunk = splits[0]
print(sample_chunk.page_content[:750])
print("\nMetadata:", sample_chunk.metadata)
# Out:
# VETERINARY PRACTICE GUIDELINES
# 2021 AAHA/AAFP Feline Life Stage Guidelines*
# Jessica Quimby, DVM, PhD, DACVIM y, Shannon Gowland, DVM, DABVP y, Hazel C. Carney, DVM, MS, DABVP,
# Theresa DePorter, DVM, MRCVS, DACVB, DECAWBM, Paula Plummer, LVT, VTS (ECC, SAIM), Jodi Westropp,
# DVM, PhD, DACVIM
# ABSTRACT
# The guidelines, authored by a Task Force ofexperts in feline clinical medicine, are an update and extension of the AAFP–AAHA
#
# Metadata: {'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 0, 'page_label': '1', 'document_type': 'cat_health_guideline', 'start_index': 0}

# %% [markdown]
# #### ❓Question #2
#
# What tradeoff do we make when choosing chunk size and chunk overlap?
#
# ##### ✅ Answer:
#
# The chunk size controls how much text each vector represents; the overlap keeps nearby context from being lost at chunk boundaries. So smaller chunks give you more precise retrival while more overlap reduces the risk that context gets split across a boundary.
#
# Use the [Chunk Visualizer](https://chunkviz.up.railway.app/) to experiment with different chunk sizes and overlaps and see how the text boundaries change.

# %% [markdown]
# ## Task 5: Embeddings and Qdrant
#
# Now we apply the same embedding idea to every chunk from the PDF. Qdrant stores those vectors and lets us search for chunks that are close to a query in embedding space.
#
# We already created an OpenAI embedding model in the primer above. The Qdrant collection name is just a label for the set of vectors we are creating.
#
# For this notebook, Qdrant runs in memory with `location=":memory:"`. That means no Docker, no Qdrant Cloud account, and no persistence after the notebook kernel stops.

# %%
collection_name = "cat_health_guidelines"

vector_store = QdrantVectorStore.from_documents(
    documents=splits,
    embedding=embeddings,
    location=":memory:",
    collection_name=collection_name,
    force_recreate=True,
)

print(f"Embedded chunks with: {embedding_model}")
print(f"Built in-memory Qdrant collection: {collection_name}")
# Out:
# Embedded chunks with: text-embedding-3-small
# Built in-memory Qdrant collection: cat_health_guidelines

# %% [markdown]
# ## Task 6: Retrieval with Scores
#
# Before we generate answers, we should inspect retrieval directly. If retrieval returns poor context, the final answer will usually be poor too.
#
# The value `k` controls how many chunks the retriever returns. A larger `k` gives the model more context, but it can also add noise. We will start with `k = 4` and tune it later.
#
# Qdrant can return both the matching `Document` and a similarity score. This is the same ranking idea we saw with `king`, `queen`, and `cat`, now applied to PDF chunks.

# %%
def display_retrieval_results(query: str, k: int) -> list[tuple]:
    """Retrieve chunks and print a compact view of the results."""
    results = vector_store.similarity_search_with_score(query, k=k)

    for index, (doc, score) in enumerate(results, start=1):
        page = doc.metadata.get("page")
        page_display = page + 1 if isinstance(page, int) else "unknown"
        start_index = doc.metadata.get("start_index", "unknown")
        preview = doc.page_content[:350].replace("\n", " ")

        print(f"Source {index} | score={score:.3f} | page={page_display} | start_index={start_index}")
        print(preview)
        print("-" * 80)

    return results

# %%
retrieval_k = 4
retrieval_query = "What signs suggest that a cat should be seen by a veterinarian?"
retrieved_results = display_retrieval_results(retrieval_query, k=retrieval_k)
# Out:
# Source 1 | score=0.590 | page=10 | start_index=4373
# Senior cats exhibiting new or unusual behavior should be evaluated for medical conditions. 12 Changes in litter box usage may indicate urinary tract disease, constipation, or diabetes but may also be due to reduced musculoskeletal strength, impaired balance, or onset of pain. V ocali- zation, especially nighttime waking, is a common concern and may
# --------------------------------------------------------------------------------
# Source 2 | score=0.563 | page=12 | start_index=1954
# is noted by the owner, the kitten should be evaluated for underlying conditions such as congenital abnormalities of the lower urinary or GI tract, GI parasites, or other infectious diseases. Mature adult and senior cats may house-soil secondarily to medical or behavioral conditions. Clients should be encouraged to seek veterinary assistance promptl
# --------------------------------------------------------------------------------
# Source 3 | score=0.561 | page=6 | start_index=2030
# each life stage, relating this to the patient, and reviewing subtle signs of anxiety, illness, and pain in cats encourages clients to be vigilant and seek care early in the course of disease. 14 V eterinarians should educate owners of purebred cats about breed predispositions, keeping in mind that most North American cats are not purebred, and that
# --------------------------------------------------------------------------------
# Source 4 | score=0.556 | page=8 | start_index=0
# Detecting signs of pain or anxiety and evaluation of quality of life are most commonly of concern in the mature adult or senior cat but may be relevant at any life stage. During the physical examination, particular focus is on pain assessment and abdominal and thyroid palpation. A detailed mus- culoskeletal examination to detect signs of osteoarthr
# --------------------------------------------------------------------------------

# %% [markdown]
# #### ❓Question #3
#
# What does a similarity score help you understand, and what does it not prove by itself?
#
# ##### ✅ Answer:
#
# Similarity score tells you how close things are within an embedding space but is not an indicator as to whether its a quality response to the question or prompt provided.

# %% [markdown]
# ## Task 7: Retrieval Augmented Generation
#
# Now we combine retrieval with generation. We will use a two-step RAG pattern:
#
# 1. Retrieve relevant chunks from Qdrant
# 2. Put those chunks into the prompt and ask the model to answer from the context
#
# This is intentionally simpler than an agent. We always retrieve before answering, which makes the vector retrieval mechanics easy to inspect.
#
# For generation, we will use `gpt-5.4-mini`.

# %%
chat_model = "gpt-5.4-mini"
llm = ChatOpenAI(model=chat_model)

RAG_SYSTEM_PROMPT = """You are a cat health guideline assistant in a vector RAG lesson.

Use only the provided context to answer the user's question.
If the context does not contain enough information, say: "I don't have enough information in the provided cat health guideline PDF to answer that."

Cite the retrieved sources inline using labels like [Source 1] or [Source 2].
Do not diagnose, prescribe medication, or replace a veterinarian.
For diagnosis, treatment decisions, medication questions, or urgent symptoms, recommend contacting a veterinarian.
Keep the answer concise and practical."""

RAG_USER_PROMPT = """Context:
{context}

Question: {question}

Answer from the context above."""

rag_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", RAG_SYSTEM_PROMPT),
        ("human", RAG_USER_PROMPT),
    ]
)

rag_chain = rag_prompt | llm | StrOutputParser()

# %%
def format_context(scored_docs: list[tuple]) -> str:
    """Convert retrieved documents into a source-labeled context string."""
    formatted_chunks = []

    for index, (doc, score) in enumerate(scored_docs, start=1):
        page = doc.metadata.get("page")
        page_display = page + 1 if isinstance(page, int) else "unknown"
        source = doc.metadata.get("source", "unknown source")

        formatted_chunks.append(
            f"[Source {index}] {source}, page {page_display}, score {score:.3f}\n"
            f"{doc.page_content}"
        )

    return "\n\n".join(formatted_chunks)


def answer_question(question: str, k: int) -> dict:
    """Run retrieve-then-generate and return the answer plus source metadata."""
    scored_docs = vector_store.similarity_search_with_score(question, k=k)
    context = format_context(scored_docs)
    answer = rag_chain.invoke({"context": context, "question": question})

    sources = []
    for index, (doc, score) in enumerate(scored_docs, start=1):
        page = doc.metadata.get("page")
        sources.append(
            {
                "source_label": f"Source {index}",
                "file": doc.metadata.get("source"),
                "page": page + 1 if isinstance(page, int) else None,
                "start_index": doc.metadata.get("start_index"),
                "score": score,
            }
        )

    return {
        "question": question,
        "answer": answer,
        "sources": sources,
        "context": scored_docs,
    }

# %% [markdown]
# Before calling the model, inspect the formatted context. This is the exact text that will be inserted into the RAG prompt.

# %%
example_context = format_context(retrieved_results[:2])
print(example_context[:2000])
# Out:
# [Source 1] cat_health_guidelines.pdf, page 10, score 0.590
# Senior cats exhibiting new or unusual behavior should be evaluated for
# medical conditions.
# 12 Changes in litter box usage may indicate urinary
# tract disease, constipation, or diabetes but may also be due to reduced
# musculoskeletal strength, impaired balance, or onset of pain. V ocali-
# zation, especially nighttime waking, is a common concern and may
# represent sensory changes (declin ing hearing and vision), cognitive
# dysfunction syndrome, pain, hyper thyroidism, or hypertension. V et-
#
# [Source 2] cat_health_guidelines.pdf, page 12, score 0.563
# is noted by the owner, the kitten should be evaluated for underlying
# conditions such as congenital abnormalities of the lower urinary or GI
# tract, GI parasites, or other infectious diseases. Mature adult and senior
# cats may house-soil secondarily to medical or behavioral conditions.
# Clients should be encouraged to seek veterinary assistance promptly, in
# order to diagnose life-threatening conditions such as urinary tract
# blockage, and to avoid having the behavior become entrenched.

# %%
answer_k = 4

result = answer_question(
    "What are signs that my cat may need veterinary attention?",
    k=answer_k,
)

print(result["answer"])
print("\nSources:")
for source in result["sources"]:
    print(source)
# Out:
# Signs that may mean your cat needs veterinary attention include:
#
# - **Reduced grooming** or **changes in grooming habits** [Source 1][Source 4]
# - **Increased grooming** that may suggest a skin problem, allergy, or other dermatologic issue [Source 4]
# - **Changes in litter box usage**, which can be linked to urinary tract disease, constipation, diabetes, reduced strength, balance problems, or pain [Source 2]
# - **New or unusual behavior** in a senior cat [Source 2]
# - **Nighttime waking or increased vocalization**, which may be related to sensory changes, cognitive dysfunction, pain, hyperthyroidism, or hypertension [Source 2]
# - Signs of **pain**, **anxiety**, or reduced mobility [Source 3]
# - **Abdominal or thyroid changes** noted on exam, or signs of **osteoarthritis/joint pain** [Source 3]
#
# If you notice any of these, especially if they are new, worsening, or affecting a senior cat, contact a veterinarian for evaluation.
#
# Sources:
# {'source_label': 'Source 1', 'file': 'cat_health_guidelines.pdf', 'page': 8, 'start_index': 767, 'score': 0.5959032957573506}
# {'source_label': 'Source 2', 'file': 'cat_health_guidelines.pdf', 'page': 10, 'start_index': 4373, 'score': 0.5824504954022338}
# {'source_label': 'Source 3', 'file': 'cat_health_guidelines.pdf', 'page': 8, 'start_index': 0, 'score': 0.5533412224572473}
# {'source_label': 'Source 4', 'file': 'cat_health_guidelines.pdf', 'page': 8, 'start_index': 370, 'score': 0.5332500999110359}

# %% [markdown]
# ### Vibe Check Queries
#
# Run a few questions that should be answerable from a cat health guideline PDF. Then run one question that may not be answerable and confirm the assistant says it does not have enough information.

# %%
vibe_check_questions = [
    "What preventive care is recommended for cats?",
    "What symptoms should make me call a veterinarian?",
    "What should I know about feeding a healthy adult cat?",
    "Can my cat help me file my taxes?",
]

for question in vibe_check_questions:
    print("Question:", question)
    result = answer_question(question, k=answer_k)
    print(result["answer"])
    print("Context:", display_retrieval_results(question, k=retrieval_k))
    print("=" * 100)
# Out:
# Question: What preventive care is recommended for cats?
# The guideline emphasizes **preventive healthcare strategies** and **personalized risk assessment** throughout a cat’s life [Source 2]. It also notes that **routine, regular use of broad-spectrum parasite products** is likely beneficial for most pet cats, and that cats with **outdoor exposure, travel, boarding, grooming, or certain geographic risks** may need extra parasite prevention measures [Source 4].
#
# For broader preventive care, the guideline also points readers to **infection control, prevention, and biosecurity** practices [Source 1].
#
# If you want, I can help summarize this into a simple cat wellness checklist.
# Source 1 | score=0.647 | page=21 | start_index=7032
# Prevention. Available at: https://www.cdc.gov/healthypets/index.html. 129. Stull JW , Bjorvik E, Bub J, et al. 2018 AAHA infection control, pre- vention, and biosecurity guidelines. J Am Anim Hosp Assoc 2018;54: 297–326. Available at: https://www.aaha.org/biosecurity. 2021 AAHA/AAFP Feline Life Stage Guidelines JAAHA.ORG 71
# --------------------------------------------------------------------------------
# Source 2 | score=0.638 | page=2 | start_index=821
# alized risk assessment, preventive healthcare strategies, and treat- ment pathways that evolve as the cat matures. An evidence-guided framework for managing a cat ’s healthcare throughout its lifetime has never been more important in feline practice than it is now. Cats are the most popular pet in the United States. 1 A great anomaly in feline prac
# --------------------------------------------------------------------------------
# Source 3 | score=0.635 | page=6 | start_index=4500
# preventive healthcare from a mature adult indoor cat living in a retirement home and interacting with residents. For further infor- mation, readers are referred to the 2019 AAFP Feline Zoonoses Guidelines 17 and the 2020 AAFP Feline Retrovirus Testing and Man- agement Guidelines.18 The role and relationship of the cat with re- spect to the client (
# --------------------------------------------------------------------------------
# Source 4 | score=0.634 | page=15 | start_index=1982
# combined with parasite prophylaxis, decrease environmental con- tamination with infectious and zoonotic agents such as hookworms and Toxoplasma gondii. 33 Routine, regular use of broad-spectrum products is likely to be beneﬁcial for the majority of pet cats, regardless of lifestyle. Certain outdoor lifestyles, geographic location, and whether a cat
# --------------------------------------------------------------------------------
# Context: [(Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 20, 'page_label': '21', 'document_type': 'cat_health_guideline', 'start_index': 7032, '_id': 'b4fd2e3dd74047b8aa0276943b05a8e9', '_collection_name': 'cat_health_guidelines'}, page_content='Prevention. Available at: https://www.cdc.gov/healthypets/index.html.\n129. Stull JW , Bjorvik E, Bub J, et al. 2018 AAHA infection control, pre-\nvention, and biosecurity guidelines. J Am Anim Hosp Assoc 2018;54:\n297–326. Available at: https://www.aaha.org/biosecurity.\n2021 AAHA/AAFP Feline Life Stage Guidelines\nJAAHA.ORG 71'), 0.6467229673927366), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 1, 'page_label': '2', 'document_type': 'cat_health_guideline', 'start_index': 821, '_id': '50a12a11a25f4052b2e2ae191212ec12', '_collection_name': 'cat_health_guidelines'}, page_content='alized risk assessment, preventive healthcare strategies, and treat-\nment pathways that evolve as the cat matures.\nAn evidence-guided framework for managing a cat ’s healthcare\nthroughout its lifetime has never been more important in feline\npractice than it is now. Cats are the most popular pet in the United\nStates.\n1 A great anomaly in feline practice is that although most\nowners consider their cats to be family members, cats are sub-'), 0.6377524035509055), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 5, 'page_label': '6', 'document_type': 'cat_health_guideline', 'start_index': 4500, '_id': '4f999d6318384d8cb985e9f7c180ce56', '_collection_name': 'cat_health_guidelines'}, page_content='preventive healthcare from a mature adult indoor cat living in a\nretirement home and interacting with residents. For further infor-\nmation, readers are referred to the 2019 AAFP Feline Zoonoses\nGuidelines\n17 and the 2020 AAFP Feline Retrovirus Testing and Man-\nagement Guidelines.18 The role and relationship of the cat with re-\nspect to the client (i.e., the human –cat bond and the care philosophy\nof the owner) is also essential to understand.'), 0.6354915851612156), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 14, 'page_label': '15', 'document_type': 'cat_health_guideline', 'start_index': 1982, '_id': '554d59bacc4f4611a6cdaf1b560a3ed7', '_collection_name': 'cat_health_guidelines'}, page_content='combined with parasite prophylaxis, decrease environmental con-\ntamination with infectious and zoonotic agents such as hookworms\nand Toxoplasma gondii.\n33\nRoutine, regular use of broad-spectrum products is likely to be\nbeneﬁcial for the majority of pet cats, regardless of lifestyle. Certain\noutdoor lifestyles, geographic location, and whether a cat spends time\naway from the home (travel, boarding facilities, groomer, etc.) may\nincrease the existing risk of parasitic infection. Thus, recommen-'), 0.6338787913590298)]
# ====================================================================================================
# Question: What symptoms should make me call a veterinarian?
# You should call a veterinarian promptly if you notice:
#
# - **Changes in litter box use** — this may indicate **urinary tract disease, constipation, or diabetes** [Source 2]
# - **House-soiling or inappropriate elimination**, especially if it may be related to a medical problem, because serious issues like **urinary tract blockage** can be life-threatening [Source 1]
# - **New or unusual behavior in a senior cat** [Source 2]
# - **Vocalization, especially nighttime waking** [Source 2]
# - Signs that may reflect **pain, decreased hearing or vision, cognitive changes, hyperthyroidism, or hypertension** [Source 2]
# - **Vomiting, vomiting hairballs, diarrhea, or other chronic GI signs** [Source 3]
# - **Weight changes** or concerns about chronic gastrointestinal disease [Source 3]
#
# If the symptoms are urgent or severe, contact a veterinarian right away.
# Source 1 | score=0.436 | page=12 | start_index=1954
# is noted by the owner, the kitten should be evaluated for underlying conditions such as congenital abnormalities of the lower urinary or GI tract, GI parasites, or other infectious diseases. Mature adult and senior cats may house-soil secondarily to medical or behavioral conditions. Clients should be encouraged to seek veterinary assistance promptl
# --------------------------------------------------------------------------------
# Source 2 | score=0.429 | page=10 | start_index=4373
# Senior cats exhibiting new or unusual behavior should be evaluated for medical conditions. 12 Changes in litter box usage may indicate urinary tract disease, constipation, or diabetes but may also be due to reduced musculoskeletal strength, impaired balance, or onset of pain. V ocali- zation, especially nighttime waking, is a common concern and may
# --------------------------------------------------------------------------------
# Source 3 | score=0.418 | page=7 | start_index=2364
# exercise tolerance. Asking speci ﬁc questions concerning whether vomiting, vom- iting hairballs, or diarrhea is occurring, and the frequency of each, is recommended as some clients may consider vomiting or vomiting hairballs to be normal for their cat. Additionally, discuss the im- portance of monitoring weight, and ask about any chronic enter- opa
# --------------------------------------------------------------------------------
# Source 4 | score=0.410 | page=10 | start_index=4793
# dysfunction syndrome, pain, hyper thyroidism, or hypertension. V et- erinary visits may be more challenging for the senior cat, in part be- cause many cat owners do not seek wellness visits, but present their cats only for acute care. 3 The use of pheromones or pre–veterinary visit pharmaceuticals such as gabapentin or trazodone may reduce stress w
# --------------------------------------------------------------------------------
# Context: [(Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 11, 'page_label': '12', 'document_type': 'cat_health_guideline', 'start_index': 1954, '_id': 'bf140f3fe2544516b7a262b9a1a90017', '_collection_name': 'cat_health_guidelines'}, page_content='is noted by the owner, the kitten should be evaluated for underlying\nconditions such as congenital abnormalities of the lower urinary or GI\ntract, GI parasites, or other infectious diseases. Mature adult and senior\ncats may house-soil secondarily to medical or behavioral conditions.\nClients should be encouraged to seek veterinary assistance promptly, in\norder to diagnose life-threatening conditions such as urinary tract\nblockage, and to avoid having the behavior become entrenched.'), 0.43564333911836484), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 9, 'page_label': '10', 'document_type': 'cat_health_guideline', 'start_index': 4373, '_id': '16aa8570f44344d39da2673450402ee4', '_collection_name': 'cat_health_guidelines'}, page_content='Senior cats exhibiting new or unusual behavior should be evaluated for\nmedical conditions.\n12 Changes in litter box usage may indicate urinary\ntract disease, constipation, or diabetes but may also be due to reduced\nmusculoskeletal strength, impaired balance, or onset of pain. V ocali-\nzation, especially nighttime waking, is a common concern and may\nrepresent sensory changes (declin ing hearing and vision), cognitive\ndysfunction syndrome, pain, hyper thyroidism, or hypertension. V et-'), 0.42870199671022846), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 6, 'page_label': '7', 'document_type': 'cat_health_guideline', 'start_index': 2364, '_id': 'be930f29538c4fc5b77c79abdf6b3cee', '_collection_name': 'cat_health_guidelines'}, page_content='exercise tolerance.\nAsking speci ﬁc questions concerning whether vomiting, vom-\niting hairballs, or diarrhea is occurring, and the frequency of each, is\nrecommended as some clients may consider vomiting or vomiting\nhairballs to be normal for their cat. Additionally, discuss the im-\nportance of monitoring weight, and ask about any chronic enter-\nopathy or gastrointestinal (GI) signs that could indicate early stages of\ndisease.\nMature Adult and Senior Cats'), 0.4177496361915136), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 9, 'page_label': '10', 'document_type': 'cat_health_guideline', 'start_index': 4793, '_id': '558fe2a4a43f4bbfb2cabf68a6a7955c', '_collection_name': 'cat_health_guidelines'}, page_content='dysfunction syndrome, pain, hyper thyroidism, or hypertension. V et-\nerinary visits may be more challenging for the senior cat, in part be-\ncause many cat owners do not seek wellness visits, but present their\ncats only for acute care.\n3 The use of pheromones or pre–veterinary visit\npharmaceuticals such as gabapentin or trazodone may reduce stress\nwhile allowing thorough evaluations.\n68–71 As many senior patients may\nb ...
# ====================================================================================================
# Question: What should I know about feeding a healthy adult cat?
# For a healthy adult cat, feeding should be based on the cat’s life stage, body condition score, muscle condition, neuter status, health status, and activity level [Source 2]. To help prevent nutrient deficiencies, choose a diet labeled with an Association of American Feed Control Officials statement of nutritional adequacy, and avoid raw or dehydrated non-sterilized animal-origin foods, including treats [Source 4].
#
# Neutering can increase obesity risk, especially in males, so monitoring and controlling calorie intake is important; free-choice feeding can lead to overconsumption [Source 3]. If you’re unsure about the right amount for your cat, I don’t have enough information in the provided cat health guideline PDF to answer that.
# Source 1 | score=0.626 | page=14 | start_index=781
# Mature Adult and Senior Cats Mature adult and senior cats have changing dietary needs, and it is extremely important to provide guidance on daily feeding amounts. DER for mature adult cats (aged 7 –10 years) may be equivalent to RER, although adjustments should be made based on the needs of the individual patient. For senior cats (greater than 10 y
# --------------------------------------------------------------------------------
# Source 2 | score=0.623 | page=13 | start_index=3992
# with weight gain, 89 this is an excellent time to evaluate the nutri- tional needs, obesity risks, and prevention strategies for the indi- vidual patient. Recommendations can be found in the AAFP ’s Feline Feeding Programs Consensus Statement. 19 Young Adult Cats Energy requirements of cats are in ﬂuenced by a variety of factors including age (i.e.
# --------------------------------------------------------------------------------
# Source 3 | score=0.606 | page=13 | start_index=5213
# struction,95 and, according to one study, an increase in the preva- lence of oral disease. 93 Neutering is a risk factor for obesity in cats, especially males, 96 and dietary energy restriction may be appropriate to prevent weight gain. 97 Free-choice feeding is a common strategy used by cat owners and can predispose to overconsumption. Maintenance
# --------------------------------------------------------------------------------
# Source 4 | score=0.600 | page=13 | start_index=2019
# could result in health problems. 83 No matter the life stage, to help avoid potential nutrient insufﬁciencies, cats should be fed diets labeled with an Association of American Feed Control Of ﬁcials statement of nutritional adequacy. AAHA and the AAFP do not advocate or en- dorse feeding cats any raw or dehydrated non-sterilized foods, in- cluding
# --------------------------------------------------------------------------------
# Context: [(Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 13, 'page_label': '14', 'document_type': 'cat_health_guideline', 'start_index': 781, '_id': '542f125c60e54d3db5df353d68e3776b', '_collection_name': 'cat_health_guidelines'}, page_content='Mature Adult and Senior Cats\nMature adult and senior cats have changing dietary needs, and it is\nextremely important to provide guidance on daily feeding amounts.\nDER for mature adult cats (aged 7 –10 years) may be equivalent to\nRER, although adjustments should be made based on the needs of\nthe individual patient. For senior cats (greater than 10 years of age),\nthe RER will need to be multiplied by a factor of 10 –20%, and in\nsome cases as high as 25%.\n101 Senior cats may also experience a'), 0.6261172362752284), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 12, 'page_label': '13', 'document_type': 'cat_health_guideline', 'start_index': 3992, '_id': 'e7b452eadedb49a29e05238fcdc190d3', '_collection_name': 'cat_health_guidelines'}, page_content='with weight gain,\n89 this is an excellent time to evaluate the nutri-\ntional needs, obesity risks, and prevention strategies for the indi-\nvidual patient. Recommendations can be found in the AAFP ’s Feline\nFeeding Programs Consensus Statement.\n19\nYoung Adult Cats\nEnergy requirements of cats are in ﬂuenced by a variety of factors\nincluding age (i.e., life stage), BCS, MCS, neuter status, health status,\nand activity level. Using indirect calorimetry, young adult active cats'), 0.6233482716258152), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 12, 'page_label': '13', 'document_type': 'cat_health_guideline', 'start_index': 5213, '_id': 'd6619d1fc91742a6919eeab530c26a18', '_collection_name': 'cat_health_guidelines'}, page_content='struction,95 and, according to one study, an increase in the preva-\nlence of oral disease. 93\nNeutering is a risk factor for obesity in cats, especially males, 96\nand dietary energy restriction may be appropriate to prevent weight\ngain.\n97 Free-choice feeding is a common strategy used by cat owners\nand can predispose to overconsumption. Maintenance of a healthy\nbody weight requires monitoring and control of caloric intake. A\n2021 AAHA/AAFP Feline Life Stage Guidelines\nJAAHA.ORG 63'), 0.605664047801941), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 12, 'page_label': '13', 'document_type': 'cat_health_guideline', 'start_index': 2019, '_id': '65f470b9ba3c49f2924d2aafa61ea1d8', '_collection_name': 'cat_health_guidelines'}, page_content='could result in health problems.\n83 No matter the life stage, to help\navoid potential nutrient insufﬁciencies, cats should be fed diets labeled\nwith an Association of American Feed Control Of ﬁcials statement of\nnutritional adequacy. AAHA and the AAFP do not advocate or en-\ndorse feeding cats any raw or dehydrated non-sterilized foods, in-\ncluding treats that are of animal origin.\n84\nIn or ...
# ====================================================================================================
# Question: Can my cat help me file my taxes?
# The provided cat health guideline PDF does not mention cats helping with taxes. It does note that cats can be taught tricks and can be acclimated to grooming and medication procedures [Source 1]. I don't have enough information in the provided cat health guideline PDF to answer that.
# Source 1 | score=0.398 | page=9 | start_index=4473
# better prepared for the veterinary examination. Interested cat owners can also teach their cats agility, fetching, or tricks. Moreover, cats can be taught to voluntarily accept grooming, nail trimming, instillation of ear treatments, application of topical antiparasitics, and admin- istration of medications both orally and subcutaneously. Ultimatel
# --------------------------------------------------------------------------------
# Source 2 | score=0.389 | page=19 | start_index=1576
# certiﬁcate. 11. AAFP . AAFP Cat Friendly Practices. Available at: catvets.com/cfp. 12. Pittari J, Rodan I, Beekman G, et al. American Association of Feline Practitioners. Senior care guidelines. J Feline Med Surg 2009;11:763–78. 13. AAFP Position Statement. Early spay a nd castration. Available at: catvets. com/public/PDFs/PositionStatements/EarlyS
# --------------------------------------------------------------------------------
# Source 3 | score=0.369 | page=10 | start_index=1994
# more costly to treat. Clients should be educated about the subtle changes in behavior and day-to-day life of the cat that may possibly be signi ﬁcant. Encouraging owners to routinely record behaviors in a journal and/or with photos and video will provide a basis for documenting any such changes. Simply asking the client, “Is your cat happy? ” may h
# --------------------------------------------------------------------------------
# Source 4 | score=0.360 | page=20 | start_index=770
# 50. Koch CS. T eaching your pet to take medication. Available at: https:// www.lincolnlandac.com/sites/site-1900/documents/Medicating%20your% 20pet2.10.14.pdf. 51. AAFP . Claw counseling: helping clients live alongside cats with claws. Available at: catvets.com/public/PDFs/PositionStatements/Scratching/Claw- Counseling.pdf. 52. Wilson C, Bain M, De
# --------------------------------------------------------------------------------
# Context: [(Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 8, 'page_label': '9', 'document_type': 'cat_health_guideline', 'start_index': 4473, '_id': 'a4930dee05404004a6afede3e86178d6', '_collection_name': 'cat_health_guidelines'}, page_content='better prepared for the veterinary examination. Interested cat owners\ncan also teach their cats agility, fetching, or tricks. Moreover, cats can\nbe taught to voluntarily accept grooming, nail trimming, instillation\nof ear treatments, application of topical antiparasitics, and admin-\nistration of medications both orally and subcutaneously. Ultimately,\nalmost every cat is going to require medication at some time in its life,\nso it is prudent to acclimate cats to these types of procedures.'), 0.3983703473071011), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 18, 'page_label': '19', 'document_type': 'cat_health_guideline', 'start_index': 1576, '_id': '6eca2d97f4744de597ee4b59de09c6a1', '_collection_name': 'cat_health_guidelines'}, page_content='certiﬁcate.\n11. AAFP . AAFP Cat Friendly Practices. Available at: catvets.com/cfp.\n12. Pittari J, Rodan I, Beekman G, et al. American Association of Feline\nPractitioners. Senior care guidelines. J Feline Med Surg 2009;11:763–78.\n13. AAFP Position Statement. Early spay a nd castration. Available at: catvets.\ncom/public/PDFs/PositionStatements/EarlySpay&Neuter.pdf.\n14. AAFP . Client brochures for cat owners. How do I know if my cat is in'), 0.38864342275748937), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 9, 'page_label': '10', 'document_type': 'cat_health_guideline', 'start_index': 1994, '_id': '36f069cadc9347edadc65d008bcd83d9', '_collection_name': 'cat_health_guidelines'}, page_content='more costly to treat. Clients should be educated about the subtle\nchanges in behavior and day-to-day life of the cat that may possibly\nbe signi ﬁcant. Encouraging owners to routinely record behaviors in\na journal and/or with photos and video will provide a basis for\ndocumenting any such changes. Simply asking the client, “Is your\ncat happy? ” may help them think about their cat ’s welfare.\nUrine marking is most often displayed by intact male cats,'), 0.3685742856450712), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 19, 'page_label': '20', 'document_type': 'cat_health_guideline', 'start_index': 770, '_id': '08d090859fd34974be1931af9c58f3f9', '_collection_name': 'cat_health_guidelines'}, page_content='50. Koch CS. T eaching your pet to take medication. Available at: https://\nwww.lincolnlandac.com/sites/site-1900/documents/Medicating%20your%\n20pet2.10.14.pdf.\n51. AAFP . Claw counseling: helping clients live alongside cats with claws.\nAvailable at: catvets.com/public/PDFs/PositionStatements/Scratching/Claw-\nCounseling.pdf.\n52. Wilson C, Bain M, DePorter T, et al. Owner observations regarding cat\nscratching behavior: an internet-based survey.JF e l i n eM e dS u r g2016;1 ...
# ====================================================================================================

# %% [markdown]
# #### ❓Question #4
#
# For the vibe check queries above, did the retrieved context seem relevant before generation? Why or why not?
#
# ##### ✅ Answer:
#
# _Write your answer here._

# %% [markdown]
# ## 🏗️ Activity: Tune Retrieval Quality
#
# Improve retrieval quality by changing one or more of these values:
#
# - The chunk size
# - The chunk overlap
# - The retrieval `k`
# - The wording of the retrieval query
#
# Suggested workflow:
#
# 1. Pick one test question.
# 2. Inspect the retrieved chunks and scores.
# 3. Change one retrieval setting.
# 4. Rebuild the splitter and vector store.
# 5. Compare whether the retrieved chunks became more relevant.
#
# When you are done, write down what changed and whether the final answer improved.

# %%
# Activity workspace
# Try retrieval tuning here.

test_question = "What symptoms should make me call a veterinarian?" 

print("=== BASELINE ===")
display_retrieval_results(test_question, k=4)

tuned_query = "What signs suggest that a cat should be seen by a veterinarian?"  # rephrased question
print("=== TUNED QUERY ===")
display_retrieval_results(tuned_query, k=4)
# Out:
# === BASELINE ===
# Source 1 | score=0.436 | page=12 | start_index=1954
# is noted by the owner, the kitten should be evaluated for underlying conditions such as congenital abnormalities of the lower urinary or GI tract, GI parasites, or other infectious diseases. Mature adult and senior cats may house-soil secondarily to medical or behavioral conditions. Clients should be encouraged to seek veterinary assistance promptl
# --------------------------------------------------------------------------------
# Source 2 | score=0.429 | page=10 | start_index=4373
# Senior cats exhibiting new or unusual behavior should be evaluated for medical conditions. 12 Changes in litter box usage may indicate urinary tract disease, constipation, or diabetes but may also be due to reduced musculoskeletal strength, impaired balance, or onset of pain. V ocali- zation, especially nighttime waking, is a common concern and may
# --------------------------------------------------------------------------------
# Source 3 | score=0.418 | page=7 | start_index=2364
# exercise tolerance. Asking speci ﬁc questions concerning whether vomiting, vom- iting hairballs, or diarrhea is occurring, and the frequency of each, is recommended as some clients may consider vomiting or vomiting hairballs to be normal for their cat. Additionally, discuss the im- portance of monitoring weight, and ask about any chronic enter- opa
# --------------------------------------------------------------------------------
# Source 4 | score=0.410 | page=10 | start_index=4793
# dysfunction syndrome, pain, hyper thyroidism, or hypertension. V et- erinary visits may be more challenging for the senior cat, in part be- cause many cat owners do not seek wellness visits, but present their cats only for acute care. 3 The use of pheromones or pre–veterinary visit pharmaceuticals such as gabapentin or trazodone may reduce stress w
# --------------------------------------------------------------------------------
# === TUNED QUERY ===
# Source 1 | score=0.590 | page=10 | start_index=4373
# Senior cats exhibiting new or unusual behavior should be evaluated for medical conditions. 12 Changes in litter box usage may indicate urinary tract disease, constipation, or diabetes but may also be due to reduced musculoskeletal strength, impaired balance, or onset of pain. V ocali- zation, especially nighttime waking, is a common concern and may
# --------------------------------------------------------------------------------
# Source 2 | score=0.563 | page=12 | start_index=1954
# is noted by the owner, the kitten should be evaluated for underlying conditions such as congenital abnormalities of the lower urinary or GI tract, GI parasites, or other infectious diseases. Mature adult and senior cats may house-soil secondarily to medical or behavioral conditions. Clients should be encouraged to seek veterinary assistance promptl
# --------------------------------------------------------------------------------
# Source 3 | score=0.561 | page=6 | start_index=2030
# each life stage, relating this to the patient, and reviewing subtle signs of anxiety, illness, and pain in cats encourages clients to be vigilant and seek care early in the course of disease. 14 V eterinarians should educate owners of purebred cats about breed predispositions, keeping in mind that most North American cats are not purebred, and that
# --------------------------------------------------------------------------------
# Source 4 | score=0.556 | page=8 | start_index=0
# Detecting signs of pain or anxiety and evaluation of quality of life are most commonly of concern in the mature adult or senior cat but may be relevant at any life stage. During the physical examination, particular focus is on pain assessment and abdominal and thyroid palpation. A detailed mus- culoskeletal examination to detect signs of osteoarthr
# --------------------------------------------------------------------------------
# [(Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 9, 'page_label': '10', 'document_type': 'cat_health_guideline', 'start_index': 4373, '_id': '714c615839a74939b1c321e1b1aedba3', '_collection_name': 'cat_health_guidelines'}, page_content='Senior cats exhibiting new or unusual behavior should be evaluated for\nmedical conditions.\n12 Changes in litter box usage may indicate urinary\ntract disease, constipation, or diabetes but may also be due to reduced\nmusculoskeletal strength, impaired balance, or onset of pain. V ocali-\nzation, especially nighttime waking, is a common concern and may\nrepresent sensory changes (declin ing hearing and vision), cognitive\ndysfunction syndrome, pain, hyper thyroidism, or hypertension. V et-'),
#   0.589555858739085),
#  (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 11, 'page_label': '12', 'document_type': 'cat_health_guideline', 'start_index': 1954, '_id': 'b8b0153f4bf046fda3b0827babd925af', '_collection_name': 'cat_health_guidelines'}, page_content='is noted by the owner, the kitten should be evaluated for underlying\nconditions such as congenital abnormalities of the lower urinary or GI\ntract, GI parasites, or other infectious diseases. Mature adult and senior\ncats may house-soil secondarily to medical or behavioral conditions.\nClients should be encouraged to seek veterinary assistance promptly, in\norder to diagnose life-threatening conditions such as urinary tract\nblockage, and to avoid having the behavior become entrenched.'),
#   0.56280926472665),
#  (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 5, 'page_label': '6', 'document_type': 'cat_health_guideline', 'start_index': 2030, '_id': 'b6a13cbf612b4415bd01c077f655929a', '_collection_name': 'cat_health_guidelines'}, page_content='each life stage, relating this to the patient, and reviewing subtle signs\nof anxiety, illness, and pain in cats encourages clients to be vigilant\nand seek care early in the course of disease.\n14 V eterinarians should\neducate owners of purebred cats about breed predispositions,\nkeeping in mind that most North American cats are not purebred,\nand that these conditions are not necessarily restricted to particular\nbreeds.\n15\nT aking a few moments to evaluate and discuss the temperament,'),
#   0.5613542146218196),
#  (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 7, 'page_label': '8', 'document_type': 'cat_health_guideline', 'start_index': 0, '_id': '9fa5e7cbfb2b4c319a084c75e3fbb4a5', '_collection_name': 'cat_health_guidelines'}, page_content='Detecting signs of pain or anxiety and evaluation of quality of life\nare most commonly of concern in the mature adult or senior cat but\nmay be relevant at any life stage.\nDuring the physical examination, particular focus is on pain\nassessment and abdominal and thyroid palpation. A detailed mus-\nculoskeletal examination to detect signs of osteoarthritis is critical as\nthis condition is one of the most signi ﬁcant and underdiagnosed\ndiseases in cats.'),
#   0.5559404777299717)]

# %% [markdown]
# ### 🏗️ Activity Notes
#
# - Setting changed:
# - Before:
# - After:
# - Did retrieval improve? Why or why not?
