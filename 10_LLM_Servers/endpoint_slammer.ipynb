# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/chris-duallogic/deployments/t521x4ox"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# Ah, the classic “wood‑chuck” conundrum! 🎶
#
# **Short answer:**
# A woodchuck would chuck as much wood as a woodchuck could **if** a woodchuck could chuck wood.
# In other words… about as much as its determination and arm‑strength allow!
#
# **Fun facts & a (non‑official) estimate:**
#
# | Source | Estimate | Notes |
# |--------|----------|-------|
# | Rodent‑researcher‑essay (cf. *Walter B. Gottschalk, 1988*) | ~700 lb (≈ 318 kg) | Based on burrow‑digging rates and “moving dirt vs. wood” equivalences. |
# | Popular folklore | 1 ft³/​second | A playful rate once cited by a “Poe‑inspired” statistic. |
# | Singer‑scientist Russ Leith (1999) | ~7 cubic feet | Tied to the volume of a three‑dimensional “mail‑box” size. |
#
# **Why the answer isn’t a hard fact**
#
# - Woodchucks (aka groundhogs) aren’t wood‑chuck‑capable by biology; they’re burrowers.
# - “Chucking” wood would be a diet‑mismatched exertion—no brochures in nature for literal log‑throwing.
# - The tongue‑twister is designed for rhythm, not truth.
#
# So if you’re planning a wood‑chucking competition, just pick any creature willing to move a handful of wood—your local raccoon is probably a better candidate! 🚀
#
# ---
#
# *Disclaimer:* The above numbers are a mix of “scientific speculation” and tongue‑twister humor. They should not be taken as definitive wildlife data.

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 21: The classic tongue‑twister answer goes: **“A wood‑chuck woul...
# Response 3: Ah, the classic tongue‑twister! While it’s mainly a playful ...
# Response 5: How much wood could a wood‑chuck chuck if a wood‑chuck could...
# Response 11: That classic tongue‑twister never really has a definitive nu...
# Response 7: The classic answer—though it’s all in good fun—comes from th...
# Response 22: **Short answer:**
#
# > “A wood‑chuck would chuck as much woo...
# Response 14: *The classic tongue‑twister answer:*
#
# > **“A woodchuck would...
# Response 1: It’s a classic tongue‑twerter, and the answer’s almost as ol...
# Response 8: Ah, the classic tongue‑twister! Though there’s no definitive...
# Response 16: A woodchuck would chuck as much wood as a woodchuck could ch...
# Response 24: A wood‑chuck would chuck roughly **700 pounds** of wood if i...
# Response 15: **Answer (Request 15)**
#
# The question has been asked so ma...
# Response 4: If a wood‑chuck could actually chuck wood, it would probably...
# Response 10: A woodchuck would chuck as much wood as it could—i.e. every ...
# Response 20: The classic answer—though it’s mostly a tongue‑twister—goes:...
# Response 17: **Answer:**
#
# A lot—if it were a real wood‑Chuck who actually...
# Response 6: The classic tongue‑twister is a playful opening to a whole w...
# Response 18: **Answer to Request 18**
#
# If a wood‐chuck really *did* get d...
# Response 13: It’s really just a playful, tongue‑twister question, but the...
# Response 12: **Answer:**
# In popular lore the answer is *“about 700 poun...
# Response 9: The old saying isn’t a strict science‑question at all – it’s...
# Response 2: The classic tongue‑twister leans on the idea that a woodchuc...
# Response 19: You’re in luck—this is one of those “tongue‑twister” questio...
# Response 23: **Answer to Request 23**
#
# > *“How much wood would a wood‑chu...
